# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('USA_Housing_Linear regression.csv')
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# ### Domain Analysis
# - Avg.Area Income- Average income of the area
# - Avg.Area House Age - Average age of the house
# - Avg.Area Number of Rooms - Average number of rooms
# - Avg.Area Number of Bedrooms - Aveage number of Bedrooms
# - Area Population - Area Of the Population
# - Price
# - Address

# %%
data.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.tail(5)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
data.drop('Address',axis=1,inplace=True)
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %% [markdown]
# #### EDA

# %%
### Univariate
sns.histplot(data=data,x='Avg. Area Income',kde=True)
plt.show()

# %% [markdown]
# - The major average income of the area lies between 60000 to 80000

# %%
sns.histplot(data=data,x='Avg. Area House Age',kde=True)
plt.show()

# %%
sns.histplot(data=data,x='Avg. Area Number of Rooms',kde=True)
plt.show()

# %%
sns.histplot(data=data,x='Avg. Area Number of Bedrooms',kde=True)
plt.show()

# %%
sns.histplot(data=data,x='Area Population',kde='True')
plt.show()

# %%
sns.histplot(data=data,x='Price',kde=True)
plt.show()

# %%
## Bivariate
sns.scatterplot(data=data,x='Avg. Area Income',y='Price')
plt.show()

# %%
sns.scatterplot(data=data,x='Avg. Area House Age',y='Price')
# Out:
# <AxesSubplot:xlabel='Avg. Area House Age', ylabel='Price'>

# %%
sns.scatterplot(data=data,x='Avg. Area Number of Rooms',y='Price')
# Out:
# <AxesSubplot:xlabel='Avg. Area Number of Rooms', ylabel='Price'>

# %%
sns.scatterplot(data=data,x='Avg. Area Number of Bedrooms',y='Price')
# Out:
# <AxesSubplot:xlabel='Avg. Area Number of Bedrooms', ylabel='Price'>

# %%
sns.scatterplot(data=data,x='Area Population',y='Price')
# Out:
# <AxesSubplot:xlabel='Area Population', ylabel='Price'>

# %%
## multivariate
sns.pairplot(data=data)

# %% [markdown]
# ### data preprocessing

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
sns.boxplot(data=data,x='Avg. Area Income')
# Out:
# <AxesSubplot:xlabel='Avg. Area Income'>

# %%
sns.boxplot(data=data,x='Avg. Area House Age')
# Out:
# <AxesSubplot:xlabel='Avg. Area House Age'>

# %%
sns.boxplot(data=data,x='Avg. Area Number of Rooms')
# Out:
# <AxesSubplot:xlabel='Avg. Area Number of Rooms'>

# %%
sns.boxplot(data=data,x='Avg. Area Number of Bedrooms')
# Out:
# <AxesSubplot:xlabel='Avg. Area Number of Bedrooms'>

# %%
sns.boxplot(data=data,x='Area Population')
# Out:
# <AxesSubplot:xlabel='Area Population'>

# %%
Q1 = data['Avg. Area Income'].quantile(0.25)
Q1
# Out:
# 61480.562388460974

# %%
Q3 = data['Avg. Area Income'].quantile(0.75)
Q3
# Out:
# 75783.33866615265

# %%
IQR = Q3-Q1
IQR
# Out:
# 14302.776277691672

# %%
lower_limit = Q1-1.5*IQR
lower_limit
# Out:
# 40026.39797192346

# %%
upper_limit = Q3+1.5*IQR
upper_limit
# Out:
# 97237.50308269015

# %%
data.loc[data['Avg. Area Income']>upper_limit]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 558       99629.013581             5.431863                   7.351398
# 693      107701.748378             7.143522                   8.518608
# 962      101928.858060             4.829586                   9.039382
# 1096      97548.310413             5.460973                   6.609396
# 1734     104702.724257             5.575523                   6.932106
# 1891     101144.323930             6.350845                   7.231771
# 2300      98468.253641             7.035383                   6.629233
# 2719     101599.670580             7.798746                   7.480512
# 3483      97881.587279             5.034395                   7.575905
# 3541     102881.120902             6.471249                   5.693536
# 3798      97669.064491             6.888763                   6.739379
# 4087     100741.298585             5.870726                   6.644853
# ...

# %%
data.loc[data['Avg. Area Income']<lower_limit]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 12        39033.809237             7.671755                   7.250029
# 39        17796.631190             4.949557                   6.713905
# 411       36100.444227             5.778489                   5.497450
# 844       39411.652788             4.385845                   7.047435
# 1271      37971.207566             4.291224                   5.807510
# 1459      35963.330809             3.438547                   8.264122
# 1597      39294.036523             5.928585                   5.960676
# 2025      38139.919045             5.577267                   6.348068
# 2092      35608.986237             6.935839                   7.827589
# 2242      38868.250311             6.965104                   8.966906
# 2597      38734.005216             5.641762                   6.297908
# 3069      35454.714659             6.855708                   6.018647
# ...

# %%
len(data.loc[data['Avg. Area Income']<lower_limit])/len(data)
# Out:
# 0.0038

# %%
len(data.loc[data['Avg. Area Income']>upper_limit])/len(data)
# Out:
# 0.0026

# %%
data.loc[data['Avg. Area Income']>upper_limit,'Avg. Area Income'] = data['Avg. Area Income'].median()

# %%
data.loc[data['Avg. Area Income']<lower_limit,'Avg. Area Income'] = data['Avg. Area Income'].median()

# %%
sns.boxplot(data=data,x='Avg. Area Income')
# Out:
# <AxesSubplot:xlabel='Avg. Area Income'>

# %%
# TO HANDLE AVERAGE HOUSE AGE OUTLIERS
Q1 = data['Avg. Area House Age'].quantile(0.25)
Q1
# Out:
# 5.322283015802158

# %%
Q3 = data['Avg. Area House Age'].quantile(0.75)
Q3
# Out:
# 6.6508084794160585

# %%
IQR = Q3-Q1
IQR
# Out:
# 1.3285254636139001

# %%
lower_limit = Q1-1.5*IQR
lower_limit
# Out:
# 3.329494820381308

# %%
upper_limit = Q3+1.5*IQR
upper_limit
# Out:
# 8.643596674836909

# %%
data.loc[data['Avg. Area House Age']<lower_limit]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 847       67474.279804             3.278228                   7.938421
# 1074      65016.223811             2.644304                   8.306304
# 1285      71152.756172             3.055370                   7.487300
# 1494      57925.044700             3.214868                   6.988818
# 1628      71721.421377             2.683043                   7.583527
# 1726      81535.149881             3.205828                   6.222769
# 1859      72139.646003             3.105751                   6.070059
# 2366      78578.343419             3.241716                   8.100932
# 2432      56402.542811             3.144894                   8.075309
# 2465      61544.583468             2.922736                   7.791620
# 3831      64644.898809             3.232059                   6.518794
# 4324      77540.894192             3.004717                   6.530858
# ...

# %%
data.loc[data['Avg. Area House Age']>upper_limit]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 918       68615.767085             8.764786                   6.122465
# 1091      75358.482596             8.991399                   7.282680
# 1777      61025.390260             8.973441                   7.905595
# 1855      68334.782565             8.688434                   8.296462
# 2898      57293.427401             9.125283                   7.780008
# 3138      77352.637603             9.008900                   5.894762
# 3388      70841.996490             8.702960                   6.315200
# 3989      65274.139949             9.519088                   6.203729
# 4859      73685.403658             8.916093                   6.291818
# 4978      80393.339500             8.899713                   5.652974
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# 918                           2.47     51791.808121  1.836978e+06
# ...

# %%
data.loc[data['Avg. Area House Age']<lower_limit,'Avg. Area House Age']=data['Avg. Area House Age'].median()

# %%
data.loc[data['Avg. Area House Age']>upper_limit,'Avg. Area House Age']=data['Avg. Area House Age'].median()

# %%
sns.boxplot(data=data,x='Avg. Area House Age')
# Out:
# <AxesSubplot:xlabel='Avg. Area House Age'>

# %%
# Avg. Area Number of Rooms Outliers
Q1 = data['Avg. Area Number of Rooms'].quantile(0.25)
Q1
# Out:
# 6.299250099611249

# %%
Q3 = data['Avg. Area Number of Rooms'].quantile(0.75)
Q3
# Out:
# 7.66587144759798

# %%
IQR = Q3-Q1
IQR
# Out:
# 1.3666213479867313

# %%
lower_limit = Q1-1.5*IQR
lower_limit
# Out:
# 4.249318077631152

# %%
upper_limit = Q3+1.5*IQR
upper_limit
# Out:
# 9.715803469578077

# %%
data.loc[data['Avg. Area Number of Rooms']<lower_limit,'Avg. Area Number of Rooms']=data['Avg. Area Number of Rooms'].median()

# %%
data.loc[data['Avg. Area Number of Rooms']>upper_limit,'Avg. Area Number of Rooms']=data['Avg. Area Number of Rooms'].median()

# %%
sns.boxplot(data=data,x='Avg. Area Number of Rooms')
# Out:
# <AxesSubplot:xlabel='Avg. Area Number of Rooms'>

# %%
Q1 = data['Area Population'].quantile(0.25)
Q1
# Out:
# 29403.928701608518

# %%
Q3 = data['Area Population'].quantile(0.75)
Q3
# Out:
# 42861.290768915605

# %%
IQR = Q3-Q1
IQR
# Out:
# 13457.362067307087

# %%
lower_limit = Q1-1.5*IQR
lower_limit
# Out:
# 9217.885600647885

# %%
upper_limit = Q3+1.5*IQR
upper_limit
# Out:
# 63047.33386987624

# %%
data.loc[data['Area Population']<lower_limit,'Area Population']=data['Area Population'].median()

# %%
data.loc[data['Area Population']>upper_limit,'Area Population']=data['Area Population'].median()

# %%
sns.boxplot(data=data,x='Area Population')
# Out:
# <AxesSubplot:xlabel='Area Population'>

# %% [markdown]
# ## Feature selection

# %%
data.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.006525
# Avg. Area House Age                  -0.006525             1.000000
# Avg. Area Number of Rooms            -0.013917            -0.011448
# Avg. Area Number of Bedrooms          0.017442             0.007103
# Area Population                      -0.001165            -0.015259
# Price                                 0.621487             0.443177
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.013917
# Avg. Area House Age                           -0.011448
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.465045
# Area Population                               -0.002468
# Price                                          0.324676
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.drop('Price',axis=1).corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## splitting data

# %%
x=data.iloc[:,0:5]
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
y=data.Price
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
## train_test_split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=40)

# %%
x_train.shape
# Out:
# (4000, 5)

# %%
x_test.shape
# Out:
# (1000, 5)

# %%
y_test
# Out:
# 4088    1.435770e+06
# 2080    1.668448e+06
# 41      1.762215e+06
# 796     1.106261e+06
# 354     1.051124e+06
#             ...
# 970     1.558759e+06
# 3716    1.393897e+06
# 315     1.024908e+06
# 2873    9.987020e+05
# 846     1.412274e+06
# Name: Price, Length: 1000, dtype: float64

# %% [markdown]
# ### Model implementation

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1434113.94121091, 1543741.92562064, 1717054.25397965,
#        1073183.93298313, 1283469.15818568,  692301.04263246,
#        1161706.79347973, 1306890.00051563, 1549480.27672619,
#        1360691.26580292, 1390883.03161029, 1237314.42724434,
#        1095427.94191494,  508979.48600503, 1251692.92890892,
#        1766720.70470089, 1574582.74643367, 1536327.60250347,
#         962280.20225585, 1029492.71690725,  663279.6417549 ,
#         740176.27172395,  945624.73129222,  605111.26398136,
#        1579805.96858624, 1770725.54131248, 1429203.8945364 ,
#        1453917.91148192, 1097551.55217184, 1821993.01562004,
#        1594225.29407488, 1214770.8729619 ,  732987.51757659,
#        1072944.04467634,  776860.62711746,  925999.61320677,
#        1329687.80614018, 1504497.40339366,  804143.91649042,
#         620935.0258215 ,  906744.62318803,  999901.6421175 ,
#        1197380.42684783, 1252125.63130677, 1811436.22207617,
# ...

# %%
y_test
# Out:
# 4088    1.435770e+06
# 2080    1.668448e+06
# 41      1.762215e+06
# 796     1.106261e+06
# 354     1.051124e+06
#             ...
# 970     1.558759e+06
# 3716    1.393897e+06
# 315     1.024908e+06
# 2873    9.987020e+05
# 846     1.412274e+06
# Name: Price, Length: 1000, dtype: float64

# %%
model.coef_
# Out:
# array([2.13322783e+01, 1.67156702e+05, 1.20046685e+05, 3.55434988e+03,
#        1.48456598e+01])

# %%
model.intercept_
# Out:
# -2621757.782420542

# %% [markdown]
# ### model evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8781263370464911

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 15160224370.339773

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 89580.8563301639

# %%
x_test.shape
# Out:
# (1000, 5)

# %%
adjusted_r2 = 1-(1-0.87)*(1000-1)/(1000-5-1)
adjusted_r2
# Out:
# 0.8693460764587525
